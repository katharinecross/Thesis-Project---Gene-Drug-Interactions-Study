# %%
# imports

import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
cluster1_df = pd.read_csv('C:/Users/student/OneDrive - Bryant University/Desktop/Honors Thesis/HonorThesisKatie/Cluster1/allSelectedGenes01Top80.csv')

# %%
cluster1_df
# Out:
#     Unnamed: 0  pr_gene_id pr_gene_symbol  \
# 0          295       22928         SEPHS2
# 1          113        4924          NUCB1
# 2          336        3033           HADH
# 3          393        5355           PLP2
# 4          287        6224          RPS20
# 5          632        6652           SORD
# 6           30        6143          RPL19
# 7          507       79602        ADIPOR2
# 8          289         894          CCND2
# 9          439       10250          SRRM1
# 10         272        1337         COX6A1
# 11         455        9167        COX7A2L
# 12         397        1965         EIF2S1
# 13         429        5111           PCNA
# 14         557        1809         DPYSL3
# 15         203       10574           CCT7
# 16         498        2114           ETS2
# 17         559        9791         PTDSS1
# 18         459       11316           COPE
# 19         275        7414            VCL
# 20         214        5351          PLOD1
# ...
